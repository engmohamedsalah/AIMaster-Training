# %% [markdown]
# <a href="https://colab.research.google.com/github/engmohamedsalah/AIMaster/blob/master/onshore_wind_farm_in_the_north_of_Germany.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train-en.csv')

# %%
df.sample(10)
# Out:
#                       Date  wind_speed48M  wind_speed100M  wind_speed152M  \
# 8898   2016-04-02 17:30:00         3.4050          3.7800          3.9800
# 33776  2016-12-17 20:00:00         3.8000          5.0200          5.6500
# 1271    2016-01-14 5:45:00         8.4175         10.3650         12.0050
# 27028  2016-10-08 14:00:00         3.4600          3.7200          3.8100
# 33626   2016-12-16 6:30:00         5.4350          7.3850          9.1650
# 3685    2016-02-08 9:15:00        13.2125         15.3475         16.7450
# 21615   2016-08-13 4:45:00         6.5250          8.4425         10.0325
# 4420    2016-02-16 1:00:00         3.4500          4.8800          5.4200
# 31584   2016-11-25 0:00:00         8.4300         10.3700         11.9600
# 35790  2017-01-07 19:30:00         4.7100          6.6550          8.2100
#
#        wind_direction48M  wind_direction100M  wind_direction152M  \
# 8898              145.50              145.50              145.50
# ...

# %%
plt.scatter(x_train["wind_speed48M"], y_train["Output"], color="cyan")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-946ead39f0e4> in <cell line: 1>()
# ----> 1 plt.scatter(x_train["wind_speed48M"], y_train["Output"], color="cyan")
#       2 plt.show()
#
# NameError: name 'x_train' is not defined
